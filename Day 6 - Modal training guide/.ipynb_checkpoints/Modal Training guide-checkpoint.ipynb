# %% [markdown]
# #### 🧠 Day 6 - ML Cheat Sheet (Models + Visualization + Workflow)
#
# ## 🚀 Goal
#
# This file serves as a quick reference for:
#
# * Model training
# * Model selection
# * Visualization techniques
# * ML workflow
#
# ---
#
# # 🔹 1. ML Model Training Template
#
# ## ✅ Universal Pattern
#
# ```python
# model = ModelName()
# model.fit(X_train, y_train)
# y_pred = model.predict(X_test)
# ```
#
# ---
#
# ## 🧠 Memory Trick
#
# **CREATE → TRAIN → PREDICT**
#
# ---
#
# ## 📌 Examples
#
# ### Linear Regression
#
# ```python
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
# ```
#
# ### Decision Tree
#
# ```python
# from sklearn.tree import DecisionTreeRegressor
# model = DecisionTreeRegressor()
# ```
#
# ### Random Forest
#
# ```python
# from sklearn.ensemble import RandomForestRegressor
# model = RandomForestRegressor()
# ```
#
# ---
#
# # 🔹 2. Model Selection Guide
#
# | Model             | When to Use                        |
# | ----------------- | ---------------------------------- |
# | Linear Regression | Linear relationship                |
# | Decision Tree     | Non-linear patterns                |
# | Random Forest     | High accuracy, reduces overfitting |
#
# ---
#
# # 🔹 3. Evaluation Metrics
#
# ```python
# from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
# ```
#
# | Metric | Meaning                 |
# | ------ | ----------------------- |
# | MAE    | Average error           |
# | RMSE   | Penalizes large errors  |
# | R²     | Model performance (0–1) |
#
# ---
#
# # 🔹 4. Visualization Cheat Sheet
#
# ## 📊 1. Distribution
#
# ```python
# sns.histplot(df['SalePrice'], kde=True)
# ```
#
# 👉 Use for: understanding data spread
#
# ---
#
# ## 📦 2. Outliers
#
# ```python
# sns.boxplot(x=df['SalePrice'])
# ```
#
# 👉 Use for: detecting extreme values
#
# ---
#
# ## 🔗 3. Relationship
#
# ```python
# sns.scatterplot(x=df['GrLivArea'], y=df['SalePrice'])
# ```
#
# 👉 Use for: feature vs target
#
# ---
#
# ## 🏷️ 4. Categorical vs Numeric
#
# ```python
# sns.boxplot(x='Neighborhood', y='SalePrice', data=df)
# ```
#
# 👉 Use for: comparing categories
#
# ---
#
# ## 🔥 5. Correlation Heatmap
#
# ```python
# sns.heatmap(df.corr(), cmap='coolwarm')
# ```
#
# 👉 Use for: finding important features
#
# ---
#
# # 🔹 5. Feature Engineering Ideas
#
# * Combine features (TotalSF)
# * Create age features (HouseAge)
# * Convert categories to numbers
#
# ---
#
# # 🔹 6. Missing Value Strategy
#
# | Type            | Strategy |
# | --------------- | -------- |
# | Categorical     | 'None'   |
# | Numerical       | Median   |
# | Logical absence | 0        |
#
# ---
#
# # 🔹 7. ML Workflow (Always Follow This)
#
# ```text
# 1. Load Data
# 2. Understand Data (EDA)
# 3. Clean Data
# 4. Feature Engineering
# 5. Encode Data
# 6. Split Data
# 7. Train Model
# 8. Evaluate Model
# 9. Improve Model
# ```
#
# ---
#
# # 🔹 8. Common Mistakes to Avoid
#
# ❌ Jumping to model without EDA
# ❌ Not handling missing values
# ❌ Overfitting (no validation)
# ❌ Copy-pasting code without understanding
#
# ---
#
# # 🔹 9. Mental Models
#
# * Model = Student
# * fit() = Learning
# * predict() = Exam
#
# ---
#
# # 🎯 Final Note
#
# Don’t memorize code.
# Understand patterns → apply logic → practice repeatedly.
#
# ---
